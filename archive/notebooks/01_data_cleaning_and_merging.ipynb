# %%
"""
Jupytext-style script for:
01_data_cleaning_and_merging.ipynb
"""
# Out:
# '\nJupytext-style script for:\n01_data_cleaning_and_merging.ipynb\n'

# %% [markdown]
# # Title and objectives
#
# This notebook prepares cleaned and merged hydrological time series for subsequent LSTM modelling of salinity intrusion. It loads raw salinity, discharge, tidal level, and rainfall data from local folders, standardises them to a common time step, and applies simple physical range checks. Short gaps are interpolated for input variables (discharge, tide, rainfall), while salinity is left un-interpolated so that the target remains as observed. Finally, the notebook builds one merged dataset per salinity station, containing the salinity target and all input variables, and saves these to `data/clean/` for downstream modelling.

# %% [markdown]
# # Imports and basic configuration
#
# This section imports the core libraries used for the workflow: `pandas` and `numpy` for data handling, and `pathlib` for file system paths. It also defines base directories, file paths for raw inputs, and configuration options such as the resampling time step. Physical ranges and aggregation rules are specified here so they can be changed in one place if needed. By default the notebook looks for raw data under `data/raw/`, but if that folder is missing and a `DATA/` folder is present (as in this repository), it will use `DATA/` instead. Discharge, tide, and rain input files are auto-detected from subfolders, but the dictionaries can be edited at the top of the notebook if you prefer to specify a curated subset.

# %%
import re
from pathlib import Path

import numpy as np
import pandas as pd

# Base directories
BASE_DIR = Path.cwd().resolve()

# Primary assumption: data/raw/ contains raw CSVs
RAW_DIR = BASE_DIR / "data" / "raw"

# Fallback for this repository: DATA/ contains raw CSVs
alt_raw_dir = BASE_DIR / "DATA"
if not RAW_DIR.exists() and alt_raw_dir.exists():
    RAW_DIR = alt_raw_dir

# Cleaned outputs go to data/clean/
CLEAN_DIR = BASE_DIR / "data" / "clean"
CLEAN_DIR.mkdir(parents=True, exist_ok=True)

# Time step for resampling: "h" (hourly) or "D" (daily)
TIME_STEP = "h"  # change to "D" for daily

# Salinity configuration
SALINITY_FILE = RAW_DIR / "salinity_all_stations.csv"
SALINITY_TIME_COL = "datetime"


def infer_station_id_from_filename(filename: str) -> str:
    """
    Infer a station identifier from a file name.

    Rules:
    - If the stem contains [Station Name], return the bracketed part with spaces removed.
    - Else if the stem matches NAME_YYYY_YYYY, return NAME.
    - Otherwise return the stem.
    """
    stem = Path(filename).stem

    m_bracket = re.search(r"\[([^\]]+)\]", stem)
    if m_bracket:
        return m_bracket.group(1).replace(" ", "")

    m_range = re.match(r"^(.*)_\d{4}_\d{4}$", stem)
    if m_range:
        return m_range.group(1)

    return stem


# Auto-detect raw input files for this repository layout
SALINITY_DIR = RAW_DIR / "Hourly_Salinity_Time_Series_44stations"
Q_DIR = RAW_DIR / "Q"
WL_DIR = RAW_DIR / "WL"
PRE_DIR = RAW_DIR / "Pre"

# Dictionaries for discharge, tide (water levels), and rainfall inputs
DISCHARGE_FILES = {}
if Q_DIR.exists():
    for path in sorted(Q_DIR.glob("*.csv")):
        sid = infer_station_id_from_filename(path.name)
        key = f"Q_{sid}"
        DISCHARGE_FILES[key] = path

TIDE_FILES = {}
if WL_DIR.exists():
    for path in sorted(WL_DIR.glob("*.csv")):
        sid = infer_station_id_from_filename(path.name)
        key = f"H_{sid}"
        TIDE_FILES[key] = path

RAIN_FILES = {}
if PRE_DIR.exists():
    for path in sorted(PRE_DIR.glob("*.csv")):
        sid = infer_station_id_from_filename(path.name)
        key = f"rain_{sid}"
        RAIN_FILES[key] = path

# Aggregation rules when resampling
AGG_MAP = {
    "salinity": "mean",     # typical for concentration
    "discharge": "mean",    # mean discharge over interval
    "tide": "mean",         # mean water level over interval
    "rain": "sum",          # sum rainfall over interval
}

# Physical ranges for basic QC (min, max)
PHYSICAL_RANGES = {
    "salinity": (0.0, 60.0),      # g/L or ppt
    "discharge": (0.0, 50000.0),  # m^3/s
    "tide": (-5.0, 5.0),          # m relative to datum
    "rain": (0.0, 500.0),         # mm per interval
}

# Will be inferred after loading salinity data
SALINITY_STATION_COLS = None


def prepare_timeseries(df: pd.DataFrame, time_col: str | None, time_step: str, agg: str = "mean") -> pd.DataFrame:
    """
    Convert a time column to a datetime index, sort, and resample.

    Parameters
    ----------
    df : DataFrame
        Input data frame containing a time column or a DatetimeIndex.
    time_col : str or None
        Name of the time column if present. If ``None`` or ``\"auto\"``,
        the function will try to infer a suitable datetime column by
        looking for names containing 'timestamp', 'time', or 'date'.
    time_step : str
        Pandas offset alias, e.g. "H" or "D".
    agg : str
        Aggregation function name for resampling ("mean", "sum", etc.).

    Returns
    -------
    DataFrame with a DatetimeIndex resampled to the requested time step.
    """
    df = df.copy()

    col = time_col

    if col is None or str(col).lower() == "auto":
        # Try explicit salinity time column first if present
        if SALINITY_TIME_COL in df.columns:
            col = SALINITY_TIME_COL
        else:
            # Look for a column that looks like a timestamp
            candidates = []
            for c in df.columns:
                cl = str(c).lower()
                if "timestamp" in cl or "date" in cl or cl.startswith("time"):
                    candidates.append(c)
            if candidates:
                col = candidates[0]

    if col is not None and col in df.columns:
        df[col] = pd.to_datetime(df[col], errors="coerce")
        df = df.dropna(subset=[col])
        df = df.set_index(col)
    elif isinstance(df.index, pd.DatetimeIndex):
        # Already indexed by time; no action required
        pass
    else:
        raise KeyError(
            f"Could not find a suitable time column in {list(df.columns)} "
            "and index is not a DatetimeIndex."
        )

    # Normalise to timezone-naive timestamps to allow joins across series.
    if isinstance(df.index, pd.DatetimeIndex) and df.index.tz is not None:
        df.index = df.index.tz_convert(None)

    df = df.sort_index()

    if time_step is not None:
        # Keep only numeric value columns for aggregation; discard metadata.
        numeric_cols = df.select_dtypes(include=[np.number]).columns
        if len(numeric_cols) == 0:
            # No numeric columns to aggregate; return an empty frame with a DatetimeIndex.
            empty = df.iloc[0:0].copy()
            empty.index = pd.DatetimeIndex(empty.index)
            return empty
        df_numeric = df[numeric_cols]
        df = df_numeric.resample(time_step).agg(agg)

    return df


def clip_and_nan(df: pd.DataFrame, col_type: str) -> pd.DataFrame:
    """
    Clip values outside plausible physical ranges to NaN.

    Parameters
    ----------
    df : DataFrame
        Input data frame with numeric columns to be checked.
    col_type : str
        One of {"salinity", "discharge", "tide", "rain"}.

    Returns
    -------
    DataFrame with out-of-range values replaced by NaN.
    """
    if col_type not in PHYSICAL_RANGES:
        raise ValueError(f"Unknown col_type '{col_type}'. Expected one of {list(PHYSICAL_RANGES.keys())}.")

    low, high = PHYSICAL_RANGES[col_type]
    df_clipped = df.copy()

    numeric_cols = df_clipped.select_dtypes(include=[np.number]).columns
    for col in numeric_cols:
        series = df_clipped[col]
        mask = (series < low) | (series > high)
        if mask.any():
            df_clipped.loc[mask, col] = np.nan

    return df_clipped


def missing_summary(df: pd.DataFrame, label: str = "") -> pd.DataFrame:
    """
    Print and return a simple missingness summary per column.

    The summary includes total row count (n), number of missing values,
    and percentage missing for each column.
    """
    n = len(df)
    n_missing = df.isna().sum()
    pct_missing = (n_missing / n * 100) if n > 0 else np.nan

    summary = pd.DataFrame(
        {
            "n": n,
            "n_missing": n_missing,
            "pct_missing": pct_missing,
        }
    )

    print("-" * 60)
    if label:
        print(f"Missingness summary for {label}")
    else:
        print("Missingness summary")
    print(summary.round(2))

    return summary


def interpolate_short_gaps(df: pd.DataFrame, limit: int = 3) -> pd.DataFrame:
    """
    Interpolate short gaps in each numeric column using time-based interpolation.

    Parameters
    ----------
    df : DataFrame
        Input data frame with a DatetimeIndex.
    limit : int
        Maximum number of consecutive NaNs to interpolate in one gap.

    Returns
    -------
    DataFrame with short gaps interpolated; longer gaps remain as NaN.
    """
    if not isinstance(df.index, pd.DatetimeIndex):
        raise TypeError("interpolate_short_gaps expects a DataFrame with a DatetimeIndex.")

    df_interp = df.copy()

    for col in df_interp.columns:
        series = df_interp[col]
        if not np.issubdtype(series.dtype, np.number):
            continue
        df_interp[col] = series.interpolate(
            method="time",
            limit=limit,
            limit_direction="both",
        )

    return df_interp

# %% [markdown]
# # Load and inspect raw datasets
#
# In this section we load the raw salinity, discharge, tidal level, and rainfall datasets. Salinity is taken either from a pre-combined wide file (`salinity_all_stations.csv`) if it exists, or, if not, from individual station CSVs under `Hourly_Salinity_Time_Series_44stations` which are merged into a single wide table. Station columns are identified automatically as all non-time, non-metadata columns. Discharge (`Q`), tide or water level (`WL`), and rainfall (`Pre`) files are auto-detected into dictionaries so that each series is named consistently; the shapes and column names are printed so that any unexpected structure can be checked before proceeding.

# %%
# Load raw salinity data
if SALINITY_FILE.exists():
    print(f"Loading wide salinity file from {SALINITY_FILE}")
    salinity_raw = pd.read_csv(SALINITY_FILE)
else:
    salinity_dir = SALINITY_DIR
    if not salinity_dir.exists():
        raise FileNotFoundError(
            f"Could not find salinity file {SALINITY_FILE} or directory {salinity_dir}. "
            "Please update SALINITY_FILE or RAW_DIR."
        )

    print(f"Building wide salinity table from per-station files in {salinity_dir}")
    sal_frames = []
    for path in sorted(salinity_dir.glob("*.csv")):
        station_id = infer_station_id_from_filename(path.name)
        df_station = pd.read_csv(path)
        if SALINITY_TIME_COL not in df_station.columns:
            raise KeyError(f"Expected time column '{SALINITY_TIME_COL}' in {path.name}")

        value_cols = [c for c in df_station.columns if c != SALINITY_TIME_COL]
        if not value_cols:
            raise ValueError(f"No value columns found in {path.name}")

        numeric_candidates = [
            c for c in value_cols if np.issubdtype(df_station[c].dtype, np.number)
        ]
        val_col = numeric_candidates[0] if numeric_candidates else value_cols[0]

        df_station = df_station[[SALINITY_TIME_COL, val_col]].rename(
            columns={val_col: station_id}
        )
        sal_frames.append(df_station)

    if not sal_frames:
        raise RuntimeError(f"No CSV files found in {salinity_dir}")

    salinity_raw = sal_frames[0]
    for df_station in sal_frames[1:]:
        salinity_raw = salinity_raw.merge(df_station, on=SALINITY_TIME_COL, how="outer")

if SALINITY_TIME_COL not in salinity_raw.columns:
    raise KeyError(f"Expected time column '{SALINITY_TIME_COL}' in salinity data.")

# Infer station columns as all non-time, non-metadata columns
metadata_candidates = {
    SALINITY_TIME_COL.lower(),
    "station",
    "station_id",
    "station_name",
}

SALINITY_STATION_COLS = [
    col for col in salinity_raw.columns
    if col.lower() not in metadata_candidates
]

print("Detected salinity station columns:")
print(SALINITY_STATION_COLS)
print(f"\nRaw salinity shape: {salinity_raw.shape}")
print(salinity_raw.head())

# Load raw discharge data
discharge_raw = {}
if not DISCHARGE_FILES:
    print("\nNo discharge files detected. DISCHARGE_FILES is empty.")
else:
    for name, path in DISCHARGE_FILES.items():
        if not Path(path).exists():
            print(f"\n[warning] Discharge file not found for '{name}': {path}")
            continue
        df = pd.read_csv(path)
        discharge_raw[name] = df
        print(f"\nLoaded discharge series '{name}' from {path} with shape {df.shape}")
        print(df.head())

# Load raw tidal level data
tide_raw = {}
if not TIDE_FILES:
    print("\nNo tide/water-level files detected. TIDE_FILES is empty.")
else:
    for name, path in TIDE_FILES.items():
        if not Path(path).exists():
            print(f"\n[warning] Tide file not found for '{name}': {path}")
            continue
        df = pd.read_csv(path)
        tide_raw[name] = df
        print(f"\nLoaded tide series '{name}' from {path} with shape {df.shape}")
        print(df.head())

# Load raw rainfall data
rain_raw = {}
if not RAIN_FILES:
    print("\nNo rainfall files detected. RAIN_FILES is empty.")
else:
    for name, path in RAIN_FILES.items():
        if not Path(path).exists():
            print(f"\n[warning] Rain file not found for '{name}': {path}")
            continue
        df = pd.read_csv(path)
        rain_raw[name] = df
        print(f"\nLoaded rain series '{name}' from {path} with shape {df.shape}")
        print(df.head())
# Out:
# Building wide salinity table from per-station files in C:\Users\User\Desktop\Disertation\DATA\Hourly_Salinity_Time_Series_44stations
# Detected salinity station columns:
# ['AnDinh', 'AnLacTay', 'AnNinh', 'AnThuan', 'BenLuc', 'BenTrai', 'BinhDai', 'CaMau', 'CauNoi', 'CauQuan', 'DaiNgai', 'DongTam', 'GanhHao', 'GiongTrom', 'GoQuao', 'HoaBinh', 'HungMy', 'HuongMy', 'KhanhThanhTan', 'LocThuan', 'LongPhu', 'LuynhQuynh', 'MyHoa', 'MyTho', 'PhuocLong', 'RachGia', 'SocTrang', 'SonDoc', 'SongDoc', 'TamNgan', 'TanAn', 'ThanhPhu', 'ThoiBinh', 'TPBacLieu', 'TraKha', 'TranDe', 'TraVinh', 'TuyenNhon', 'VamKenh', 'VungLiem', 'XeoRo', 'XuanKhanh']
#
# Raw salinity shape: (87282, 43)
#          datetime  AnDinh  AnLacTay  AnNinh  AnThuan  BenLuc  BenTrai  \
# 0  1/1/2021 17:00     0.1       NaN     NaN      NaN     NaN      NaN
# 1  1/1/2021 19:00     0.2       NaN     NaN      NaN     NaN      NaN
# 2  1/1/2021 21:00     0.1       NaN     NaN      NaN     NaN      NaN
# 3   1/1/2021 5:00     0.1       NaN     NaN      NaN     NaN      NaN
# 4   1/1/2021 7:00     0.1       NaN     NaN      NaN     NaN      NaN
#
#    BinhDai  CaMau  CauNoi  ...  ThoiBinh  TPBacLieu  TraKha  TranDe  TraVinh  \
# 0      NaN    NaN     NaN  ...       NaN        NaN     NaN     NaN      NaN
# 1      NaN    NaN     NaN  ...       NaN        NaN     NaN     NaN      NaN
# 2      NaN    NaN     NaN  ...       NaN        NaN     NaN     NaN      NaN
# 3      NaN    NaN     NaN  ...       NaN        NaN     NaN     NaN      NaN
# 4      NaN    NaN     NaN  ...       NaN        NaN     NaN     NaN      NaN
#
#    TuyenNhon  VamKenh  VungLiem  XeoRo  XuanKhanh
# 0        NaN      NaN       NaN    NaN        NaN
# 1        NaN      NaN       NaN    NaN        NaN
# 2        NaN      NaN       NaN    NaN        NaN
# 3        NaN      NaN       NaN    NaN        NaN
# 4        NaN      NaN       NaN    NaN        NaN
#
# [5 rows x 43 columns]
#
# Loaded discharge series 'Q_MyThuan' from C:\Users\User\Desktop\Disertation\DATA\Q\Discharge.Daily Calculated@VN_019804_[My Thuan].csv with shape (2311, 10)
#   Country Code  Station Code  Parameter             Label  \
# 0           VN         19804  Discharge  Daily Calculated
# 1           VN         19804  Discharge  Daily Calculated
# 2           VN         19804  Discharge  Daily Calculated
# 3           VN         19804  Discharge  Daily Calculated
# 4           VN         19804  Discharge  Daily Calculated
#
#   Timestamp (UTC+07:00)    Value   Unit Observed or Estimated  \
# 0     2001-01-01T00:00Z   5480.0  m^3/s                     O
# 1     2001-01-02T00:00Z   7370.0  m^3/s                     O
# 2     2001-01-03T00:00Z   9900.0  m^3/s                     O
# 3     2001-01-04T00:00Z  11400.0  m^3/s                     O
# 4     2001-01-05T00:00Z  11000.0  m^3/s                     O
#
#            Approval Level            Grade
# 0  Raw - Not Yet Reviewed  Unverified data
# 1  Raw - Not Yet Reviewed  Unverified data
# 2  Raw - Not Yet Reviewed  Unverified data
# 3  Raw - Not Yet Reviewed  Unverified data
# 4  Raw - Not Yet Reviewed  Unverified data
#
# Loaded discharge series 'Q_CanTho' from C:\Users\User\Desktop\Disertation\DATA\Q\Discharge.Daily Calculated@VN_039803_[Can Tho].csv with shape (2241, 10)
#   Country Code  Station Code  Parameter             Label  \
# 0           VN         39803  Discharge  Daily Calculated
# 1           VN         39803  Discharge  Daily Calculated
# 2           VN         39803  Discharge  Daily Calculated
# 3           VN         39803  Discharge  Daily Calculated
# 4           VN         39803  Discharge  Daily Calculated
#
#   Timestamp (UTC+07:00)    Value   Unit Observed or Estimated  \
# 0     2001-01-01T00:00Z   2980.0  m^3/s                     O
# 1     2001-01-02T00:00Z   5810.0  m^3/s                     O
# 2     2001-01-03T00:00Z   9030.0  m^3/s                     O
# 3     2001-01-04T00:00Z  10600.0  m^3/s                     O
# 4     2001-01-05T00:00Z  11800.0  m^3/s                     O
#
#            Approval Level            Grade
# 0  Raw - Not Yet Reviewed  Unverified data
# 1  Raw - Not Yet Reviewed  Unverified data
# 2  Raw - Not Yet Reviewed  Unverified data
# 3  Raw - Not Yet Reviewed  Unverified data
# 4  Raw - Not Yet Reviewed  Unverified data
#
# Loaded discharge series 'Q_VamNao' from C:\Users\User\Desktop\Disertation\DATA\Q\Discharge.Daily Calculated@VN_980601_[Vam Nao].csv with shape (2455, 10)
#   Country Code  Station Code  Parameter             Label  \
# 0           VN        980601  Discharge  Daily Calculated
# 1           VN        980601  Discharge  Daily Calculated
# 2           VN        980601  Discharge  Daily Calculated
# 3           VN        980601  Discharge  Daily Calculated
# 4           VN        980601  Discharge  Daily Calculated
#
#   Timestamp (UTC+07:00)   Value   Unit Observed or Estimated  \
# 0     2001-01-01T00:00Z  3760.0  m^3/s                     O
# 1     2001-01-02T00:00Z  3840.0  m^3/s                     O
# 2     2001-01-03T00:00Z  3930.0  m^3/s                     O
# 3     2001-01-04T00:00Z  4050.0  m^3/s                     O
# 4     2001-01-05T00:00Z  3720.0  m^3/s                     O
#
#            Approval Level            Grade
# 0  Raw - Not Yet Reviewed  Unverified data
# 1  Raw - Not Yet Reviewed  Unverified data
# 2  Raw - Not Yet Reviewed  Unverified data
# 3  Raw - Not Yet Reviewed  Unverified data
# 4  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_TanChau' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_019803_[Tan Chau].csv with shape (85504, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN         19803  Water Level  Manual     1979-04-01T00:00Z
# 1           VN         19803  Water Level  Manual     1979-04-02T00:00Z
# 2           VN         19803  Water Level  Manual     1979-04-03T00:00Z
# 3           VN         19803  Water Level  Manual     1979-04-04T00:00Z
# 4           VN         19803  Water Level  Manual     1979-04-05T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   0.73    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1   0.68    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2   0.63    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3   0.59    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4   0.55    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_MyThuan' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_019804_[My Thuan].csv with shape (50904, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN         19804  Water Level  Manual     1960-06-30T00:00Z
# 1           VN         19804  Water Level  Manual     1960-07-01T00:00Z
# 2           VN         19804  Water Level  Manual     1960-07-02T00:00Z
# 3           VN         19804  Water Level  Manual     1960-07-03T00:00Z
# 4           VN         19804  Water Level  Manual     1960-07-04T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   2.52    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1   2.51    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2   2.52    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3   2.51    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4   2.61    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_MyTho' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_019805_[My Tho].csv with shape (9860, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN         19805  Water Level  Manual     1985-01-01T00:00Z
# 1           VN         19805  Water Level  Manual     1985-01-02T00:00Z
# 2           VN         19805  Water Level  Manual     1985-01-03T00:00Z
# 3           VN         19805  Water Level  Manual     1985-01-04T00:00Z
# 4           VN         19805  Water Level  Manual     1985-01-05T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   0.23    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1   0.23    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2   0.21    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3   0.26    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4   0.21    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_ChoMoi' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_019807_[Cho Moi].csv with shape (11549, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN         19807  Water Level  Manual     1980-04-01T00:00Z
# 1           VN         19807  Water Level  Manual     1980-04-02T00:00Z
# 2           VN         19807  Water Level  Manual     1980-04-03T00:00Z
# 3           VN         19807  Water Level  Manual     1980-04-04T00:00Z
# 4           VN         19807  Water Level  Manual     1980-04-05T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   0.66    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1   0.74    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2   0.82    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3   0.80    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4   0.75    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_CanTho' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_039803_[Can Tho].csv with shape (50202, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN         39803  Water Level  Manual     1979-04-01T00:00Z
# 1           VN         39803  Water Level  Manual     1979-04-02T00:00Z
# 2           VN         39803  Water Level  Manual     1979-04-03T00:00Z
# 3           VN         39803  Water Level  Manual     1979-04-04T00:00Z
# 4           VN         39803  Water Level  Manual     1979-04-05T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   0.03    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1  -0.02    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2  -0.04    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3  -0.06    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4  -0.05    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_DaiNgai' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_039812_[Dai Ngai].csv with shape (9861, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN         39812  Water Level  Manual     1985-01-01T00:00Z
# 1           VN         39812  Water Level  Manual     1985-01-02T00:00Z
# 2           VN         39812  Water Level  Manual     1985-01-03T00:00Z
# 3           VN         39812  Water Level  Manual     1985-01-04T00:00Z
# 4           VN         39812  Water Level  Manual     1985-01-05T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   0.15    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1   0.11    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2   0.09    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3   0.12    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4   0.11    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_ChoLach' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_980505_[Cho Lach].csv with shape (9131, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN        980505  Water Level  Manual     1987-01-01T00:00Z
# 1           VN        980505  Water Level  Manual     1987-01-02T00:00Z
# 2           VN        980505  Water Level  Manual     1987-01-03T00:00Z
# 3           VN        980505  Water Level  Manual     1987-01-04T00:00Z
# 4           VN        980505  Water Level  Manual     1987-01-05T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   0.66    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1   0.66    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2   0.58    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3   0.51    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4   0.51    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_VamNao' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_980601_[Vam Nao].csv with shape (48415, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN        980601  Water Level  Manual     1985-01-01T00:00Z
# 1           VN        980601  Water Level  Manual     1985-01-02T00:00Z
# 2           VN        980601  Water Level  Manual     1985-01-03T00:00Z
# 3           VN        980601  Water Level  Manual     1985-01-04T00:00Z
# 4           VN        980601  Water Level  Manual     1985-01-05T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   1.19    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1   1.16    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2   1.16    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3   1.16    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4   1.12    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_VamKenh' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_985203_[Vam Kenh].csv with shape (34273, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN        985203  Water Level  Manual     1992-01-01T00:00Z
# 1           VN        985203  Water Level  Manual     1992-01-02T00:00Z
# 2           VN        985203  Water Level  Manual     1992-01-03T00:00Z
# 3           VN        985203  Water Level  Manual     1992-01-04T00:00Z
# 4           VN        985203  Water Level  Manual     1992-01-05T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   1.14    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1   1.10    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2   1.08    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3   1.05    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4   1.02    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_TanHiep' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_986302_[Tan Hiep].csv with shape (9861, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN        986302  Water Level  Manual     1985-01-01T00:00Z
# 1           VN        986302  Water Level  Manual     1985-01-02T00:00Z
# 2           VN        986302  Water Level  Manual     1985-01-03T00:00Z
# 3           VN        986302  Water Level  Manual     1985-01-04T00:00Z
# 4           VN        986302  Water Level  Manual     1985-01-05T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   0.53    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1   0.47    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2   0.41    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3   0.41    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4   0.42    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_ViThanh' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_986801_[Vi Thanh].csv with shape (9491, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN        986801  Water Level  Manual     1985-01-01T00:00Z
# 1           VN        986801  Water Level  Manual     1985-01-02T00:00Z
# 2           VN        986801  Water Level  Manual     1985-01-03T00:00Z
# 3           VN        986801  Water Level  Manual     1985-01-04T00:00Z
# 4           VN        986801  Water Level  Manual     1985-01-05T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   0.15    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1   0.09    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2   0.07    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3   0.06    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4   0.06    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_CaiLay' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Manual@VN_988001_[Cai Lay].csv with shape (9132, 10)
#   Country Code  Station Code    Parameter   Label Timestamp (UTC+07:00)  \
# 0           VN        988001  Water Level  Manual     1987-01-01T00:00Z
# 1           VN        988001  Water Level  Manual     1987-01-02T00:00Z
# 2           VN        988001  Water Level  Manual     1987-01-03T00:00Z
# 3           VN        988001  Water Level  Manual     1987-01-04T00:00Z
# 4           VN        988001  Water Level  Manual     1987-01-05T00:00Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0   0.93    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1   0.95    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2   0.92    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3   0.86    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4   0.83    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded tide series 'H_PhungHiep' from C:\Users\User\Desktop\Disertation\DATA\WL\Water Level.Telemetry@VN_902601_[Phung Hiep].csv with shape (182035, 10)
#   Country Code  Station Code    Parameter      Label Timestamp (UTC+07:00)  \
# 0           VN        902601  Water Level  Telemetry     2018-06-15T05:45Z
# 1           VN        902601  Water Level  Telemetry     2018-06-15T06:00Z
# 2           VN        902601  Water Level  Telemetry     2018-06-15T06:15Z
# 3           VN        902601  Water Level  Telemetry     2018-06-15T06:30Z
# 4           VN        902601  Water Level  Telemetry     2018-06-15T06:45Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0  0.034    m                     O  Raw - Not Yet Reviewed  Unverified data
# 1  0.042    m                     O  Raw - Not Yet Reviewed  Unverified data
# 2  0.062    m                     O  Raw - Not Yet Reviewed  Unverified data
# 3  0.105    m                     O  Raw - Not Yet Reviewed  Unverified data
# 4  0.188    m                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_MyThuan' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_019804_[My Thuan].csv with shape (8976, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN         19804  Rainfall  Manual     2006-08-01T00:00Z    0.0
# 1           VN         19804  Rainfall  Manual     2006-08-03T00:00Z   -0.5
# 2           VN         19804  Rainfall  Manual     2006-08-04T00:00Z   -0.5
# 3           VN         19804  Rainfall  Manual     2006-08-06T00:00Z   -0.3
# 4           VN         19804  Rainfall  Manual     2006-08-07T00:00Z   -0.1
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_CaMau' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_090503_[Ca Mau].csv with shape (12054, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN         90503  Rainfall  Manual     1980-01-01T00:00Z    0.0
# 1           VN         90503  Rainfall  Manual     1980-01-02T00:00Z    0.0
# 2           VN         90503  Rainfall  Manual     1980-01-03T00:00Z    0.0
# 3           VN         90503  Rainfall  Manual     1980-01-04T00:00Z    0.4
# 4           VN         90503  Rainfall  Manual     1980-01-05T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_ViThanh' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_090504_[Vi Thanh].csv with shape (11687, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN         90504  Rainfall  Manual     1980-01-01T00:00Z    0.0
# 1           VN         90504  Rainfall  Manual     1980-01-02T00:00Z    0.0
# 2           VN         90504  Rainfall  Manual     1980-01-03T00:00Z    0.0
# 3           VN         90504  Rainfall  Manual     1980-01-04T00:00Z    0.0
# 4           VN         90504  Rainfall  Manual     1980-01-05T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_PhungHiep' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_090509_[Phung Hiep].csv with shape (11840, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN         90509  Rainfall  Manual     1980-01-01T00:00Z    0.0
# 1           VN         90509  Rainfall  Manual     1980-01-02T00:00Z    0.0
# 2           VN         90509  Rainfall  Manual     1980-01-03T00:00Z    0.0
# 3           VN         90509  Rainfall  Manual     1980-01-04T00:00Z    0.0
# 4           VN         90509  Rainfall  Manual     1980-01-05T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_DaiNgai' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_090602_[Dai Ngai].csv with shape (11962, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN         90602  Rainfall  Manual     1980-01-01T00:00Z    0.0
# 1           VN         90602  Rainfall  Manual     1980-01-02T00:00Z    0.0
# 2           VN         90602  Rainfall  Manual     1980-01-03T00:00Z    0.0
# 3           VN         90602  Rainfall  Manual     1980-01-04T00:00Z    0.0
# 4           VN         90602  Rainfall  Manual     1980-01-05T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_ChauDoc' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_100505_[Chau Doc].csv with shape (19448, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN        100505  Rainfall  Manual     1920-01-01T00:00Z    0.0
# 1           VN        100505  Rainfall  Manual     1920-01-02T00:00Z    0.0
# 2           VN        100505  Rainfall  Manual     1920-01-03T00:00Z    0.0
# 3           VN        100505  Rainfall  Manual     1920-01-04T00:00Z    0.0
# 4           VN        100505  Rainfall  Manual     1920-01-05T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_CanTho' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_100509_[Can Tho].csv with shape (19027, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN        100509  Rainfall  Manual     1920-01-01T00:00Z    0.0
# 1           VN        100509  Rainfall  Manual     1920-01-02T00:00Z    0.0
# 2           VN        100509  Rainfall  Manual     1920-01-03T00:00Z    0.0
# 3           VN        100509  Rainfall  Manual     1920-01-04T00:00Z    0.0
# 4           VN        100509  Rainfall  Manual     1920-01-05T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_TanChau' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_100513_[Tan Chau].csv with shape (2924, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN        100513  Rainfall  Manual     1997-12-31T00:00Z    0.0
# 1           VN        100513  Rainfall  Manual     1998-01-01T00:00Z    0.0
# 2           VN        100513  Rainfall  Manual     1998-01-02T00:00Z    0.0
# 3           VN        100513  Rainfall  Manual     1998-01-03T00:00Z    0.0
# 4           VN        100513  Rainfall  Manual     1998-01-04T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_ChoMoi' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_100514_[Cho Moi].csv with shape (2924, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN        100514  Rainfall  Manual     1997-12-31T00:00Z    0.0
# 1           VN        100514  Rainfall  Manual     1998-01-01T00:00Z    0.0
# 2           VN        100514  Rainfall  Manual     1998-01-02T00:00Z    0.0
# 3           VN        100514  Rainfall  Manual     1998-01-03T00:00Z    0.0
# 4           VN        100514  Rainfall  Manual     1998-01-04T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_TanHiep' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_100519_[Tan Hiep].csv with shape (2923, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN        100519  Rainfall  Manual     1997-12-31T00:00Z    0.0
# 1           VN        100519  Rainfall  Manual     1998-01-01T00:00Z    0.0
# 2           VN        100519  Rainfall  Manual     1998-01-02T00:00Z    0.0
# 3           VN        100519  Rainfall  Manual     1998-01-03T00:00Z    0.0
# 4           VN        100519  Rainfall  Manual     1998-01-04T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_MyTho' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_100605_[My Tho].csv with shape (8036, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN        100605  Rainfall  Manual     1984-12-31T00:00Z    0.0
# 1           VN        100605  Rainfall  Manual     1985-01-01T00:00Z    0.0
# 2           VN        100605  Rainfall  Manual     1985-01-02T00:00Z    0.0
# 3           VN        100605  Rainfall  Manual     1985-01-03T00:00Z    0.0
# 4           VN        100605  Rainfall  Manual     1985-01-04T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_CaiLay' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_100609_[Cai Lay].csv with shape (2924, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN        100609  Rainfall  Manual     1997-12-31T00:00Z    0.0
# 1           VN        100609  Rainfall  Manual     1998-01-01T00:00Z    0.0
# 2           VN        100609  Rainfall  Manual     1998-01-02T00:00Z    0.0
# 3           VN        100609  Rainfall  Manual     1998-01-03T00:00Z    0.0
# 4           VN        100609  Rainfall  Manual     1998-01-04T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_Batri' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_100612_[Batri].csv with shape (2557, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN        100612  Rainfall  Manual     1997-12-31T00:00Z    0.0
# 1           VN        100612  Rainfall  Manual     1998-01-01T00:00Z    0.0
# 2           VN        100612  Rainfall  Manual     1998-01-02T00:00Z    0.0
# 3           VN        100612  Rainfall  Manual     1998-01-03T00:00Z    0.0
# 4           VN        100612  Rainfall  Manual     1998-01-04T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_BenLuc' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_100613_[Ben Luc].csv with shape (2924, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN        100613  Rainfall  Manual     1997-12-31T00:00Z    0.0
# 1           VN        100613  Rainfall  Manual     1998-01-01T00:00Z    0.0
# 2           VN        100613  Rainfall  Manual     1998-01-02T00:00Z    0.0
# 3           VN        100613  Rainfall  Manual     1998-01-03T00:00Z    0.0
# 4           VN        100613  Rainfall  Manual     1998-01-04T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_CaiBe' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_100614_[Cai Be].csv with shape (2557, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN        100614  Rainfall  Manual     1997-12-31T00:00Z    0.0
# 1           VN        100614  Rainfall  Manual     1998-01-01T00:00Z    0.0
# 2           VN        100614  Rainfall  Manual     1998-01-02T00:00Z    0.0
# 3           VN        100614  Rainfall  Manual     1998-01-03T00:00Z    0.0
# 4           VN        100614  Rainfall  Manual     1998-01-04T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_VamNao' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Manual@VN_980601_[Vam Nao].csv with shape (10387, 10)
#   Country Code  Station Code Parameter   Label Timestamp (UTC+07:00)  Value  \
# 0           VN        980601  Rainfall  Manual     2007-09-02T00:00Z    7.0
# 1           VN        980601  Rainfall  Manual     2009-05-13T12:00Z    1.5
# 2           VN        980601  Rainfall  Manual     2009-05-14T00:00Z    1.2
# 3           VN        980601  Rainfall  Manual     2009-05-14T12:00Z    1.2
# 4           VN        980601  Rainfall  Manual     2009-05-15T00:00Z    0.0
#
#   Unit Observed or Estimated          Approval Level            Grade
# 0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4   mm                     O  Raw - Not Yet Reviewed  Unverified data
#
# Loaded rain series 'rain_VamKenh' from C:\Users\User\Desktop\Disertation\DATA\Pre\Rainfall.Telemetry@VN_985203_[Vam Kenh].csv with shape (299872, 10)
#   Country Code  Station Code Parameter      Label Timestamp (UTC+07:00)  \
# 0           VN        985203  Rainfall  Telemetry     2010-05-03T11:45Z
# 1           VN        985203  Rainfall  Telemetry     2010-05-03T12:00Z
# 2           VN        985203  Rainfall  Telemetry     2010-05-03T12:15Z
# 3           VN        985203  Rainfall  Telemetry     2010-05-03T12:30Z
# 4           VN        985203  Rainfall  Telemetry     2010-05-03T12:45Z
#
#    Value Unit Observed or Estimated          Approval Level            Grade
# 0    0.0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 1    0.0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 2    0.0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 3    0.0   mm                     O  Raw - Not Yet Reviewed  Unverified data
# 4    0.0   mm                     O  Raw - Not Yet Reviewed  Unverified data

# %% [markdown]
# # Standardise datetime and resample to a common time step
#
# Here we convert the datetime columns to proper `datetime64` types, set them as indexes, and resample each series to a common time step. The default resolution is hourly (`TIME_STEP = "H"`), but this can be changed to daily (`"D"`) or another appropriate interval. Salinity and most other variables are aggregated using the mean, while rainfall is aggregated using the sum to preserve totals. This step ensures that all series share a consistent temporal grid, which simplifies later merging and modelling.

# %%
# Resample salinity: keep only time and station columns
salinity_cols = [SALINITY_TIME_COL] + SALINITY_STATION_COLS
salinity_ts = prepare_timeseries(
    salinity_raw[salinity_cols],
    time_col=SALINITY_TIME_COL,
    time_step=TIME_STEP,
    agg=AGG_MAP["salinity"],
)
print(f"Salinity resampled to {TIME_STEP}: shape = {salinity_ts.shape}")

# Resample discharge series
discharge_ts = {}
for name, df_raw in discharge_raw.items():
    df_ts = prepare_timeseries(
        df_raw,
        time_col="auto",
        time_step=TIME_STEP,
        agg=AGG_MAP["discharge"],
    )
    discharge_ts[name] = df_ts
    print(f"Discharge '{name}' resampled to {TIME_STEP}: shape = {df_ts.shape}")

# Resample tidal level series
tide_ts = {}
for name, df_raw in tide_raw.items():
    df_ts = prepare_timeseries(
        df_raw,
        time_col="auto",
        time_step=TIME_STEP,
        agg=AGG_MAP["tide"],
    )
    tide_ts[name] = df_ts
    print(f"Tide '{name}' resampled to {TIME_STEP}: shape = {df_ts.shape}")

# Resample rainfall series
rain_ts = {}
for name, df_raw in rain_raw.items():
    df_ts = prepare_timeseries(
        df_raw,
        time_col="auto",
        time_step=TIME_STEP,
        agg=AGG_MAP["rain"],
    )
    rain_ts[name] = df_ts
    print(f"Rain '{name}' resampled to {TIME_STEP}: shape = {df_ts.shape}")
# Out:
# Salinity resampled to h: shape = (239493, 42)
# Discharge 'Q_MyThuan' resampled to h: shape = (61321, 2)
# Discharge 'Q_CanTho' resampled to h: shape = (61321, 2)
# Discharge 'Q_VamNao' resampled to h: shape = (61321, 2)
# Tide 'H_TanChau' resampled to h: shape = (391465, 2)
# Tide 'H_MyThuan' resampled to h: shape = (555841, 2)
# Tide 'H_MyTho' resampled to h: shape = (245425, 2)
# Tide 'H_ChoMoi' resampled to h: shape = (287089, 2)
# Tide 'H_CanTho' resampled to h: shape = (391465, 2)
# Tide 'H_DaiNgai' resampled to h: shape = (245401, 2)
# Tide 'H_ChoLach' resampled to h: shape = (227881, 2)
# Tide 'H_VamNao' resampled to h: shape = (341017, 2)
# Tide 'H_VamKenh' resampled to h: shape = (279673, 2)
# Tide 'H_TanHiep' resampled to h: shape = (245425, 2)
# Tide 'H_ViThanh' resampled to h: shape = (245401, 2)
# Tide 'H_CaiLay' resampled to h: shape = (227905, 2)
# Tide 'H_PhungHiep' resampled to h: shape = (48034, 2)
# Rain 'rain_MyThuan' resampled to h: shape = (151849, 2)
# Rain 'rain_CaMau' resampled to h: shape = (289273, 2)
# Rain 'rain_ViThanh' resampled to h: shape = (289273, 2)
# Rain 'rain_PhungHiep' resampled to h: shape = (289273, 2)
# Rain 'rain_DaiNgai' resampled to h: shape = (289273, 2)
# Rain 'rain_ChauDoc' resampled to h: shape = (771097, 2)
# Rain 'rain_CanTho' resampled to h: shape = (771385, 2)
# Rain 'rain_TanChau' resampled to h: shape = (78889, 2)
# Rain 'rain_ChoMoi' resampled to h: shape = (78889, 2)
# Rain 'rain_TanHiep' resampled to h: shape = (78889, 2)
# Rain 'rain_MyTho' resampled to h: shape = (192841, 2)
# Rain 'rain_CaiLay' resampled to h: shape = (78889, 2)
# Rain 'rain_Batri' resampled to h: shape = (78889, 2)
# Rain 'rain_BenLuc' resampled to h: shape = (78889, 2)
# Rain 'rain_CaiBe' resampled to h: shape = (78889, 2)
# Rain 'rain_VamNao' resampled to h: shape = (142321, 2)
# Rain 'rain_VamKenh' resampled to h: shape = (119189, 2)

# %% [markdown]
# # Basic quality control (ranges, missingness)
#
# This section applies simple physical range checks to each variable group to remove impossible or highly implausible values. Values outside the specified ranges (for example negative salinity or rainfall, or excessively large discharges) are replaced by `NaN` and treated as missing. After clipping, missingness is summarised per variable so that data quality can be inspected before any interpolation is applied. Salinity is cleaned but not interpolated, as it serves as the prediction target.

# %%
# Range-based QC for salinity (no interpolation here)
salinity_clean = clip_and_nan(salinity_ts, col_type="salinity")
_ = missing_summary(salinity_clean, label="salinity (after range checks, no interpolation)")

# Range-based QC for discharge
discharge_qc = {}
for name, df_ts in discharge_ts.items():
    df_qc = clip_and_nan(df_ts, col_type="discharge")
    discharge_qc[name] = df_qc

# Range-based QC for tidal level
tide_qc = {}
for name, df_ts in tide_ts.items():
    df_qc = clip_and_nan(df_ts, col_type="tide")
    tide_qc[name] = df_qc

# Range-based QC for rainfall
rain_qc = {}
for name, df_ts in rain_ts.items():
    df_qc = clip_and_nan(df_ts, col_type="rain")
    rain_qc[name] = df_qc
# Out:
# ------------------------------------------------------------
# Missingness summary for salinity (after range checks, no interpolation)
#                     n  n_missing  pct_missing
# AnDinh         239493     221601        92.53
# AnLacTay       239493     239493       100.00
# AnNinh         239493     239493       100.00
# AnThuan        239493     239493       100.00
# BenLuc         239493     239493       100.00
# BenTrai        239493     239493       100.00
# BinhDai        239493     239493       100.00
# CaMau          239493     239493       100.00
# CauNoi         239493     239493       100.00
# CauQuan        239493     239493       100.00
# DaiNgai        239493     239493       100.00
# DongTam        239493     239493       100.00
# GanhHao        239493     239493       100.00
# GiongTrom      239493     239493       100.00
# GoQuao         239493     239493       100.00
# HoaBinh        239493     239493       100.00
# HungMy         239493     239493       100.00
# HuongMy        239493     239493       100.00
# KhanhThanhTan  239493     239493       100.00
# LocThuan       239493     239493       100.00
# LongPhu        239493     239493       100.00
# LuynhQuynh     239493     239493       100.00
# MyHoa          239493     239493       100.00
# MyTho          239493     239493       100.00
# PhuocLong      239493     239493       100.00
# RachGia        239493     239493       100.00
# SocTrang       239493     239493       100.00
# SonDoc         239493     239493       100.00
# SongDoc        239493     239493       100.00
# TamNgan        239493     239493       100.00
# TanAn          239493     239493       100.00
# ThanhPhu       239493     239493       100.00
# ThoiBinh       239493     239493       100.00
# TPBacLieu      239493     239493       100.00
# TraKha         239493     239493       100.00
# TranDe         239493     239493       100.00
# TraVinh        239493     239493       100.00
# TuyenNhon      239493     239493       100.00
# VamKenh        239493     239493       100.00
# VungLiem       239493     239493       100.00
# XeoRo          239493     239493       100.00
# XuanKhanh      239493     239493       100.00

# %% [markdown]
# # Interpolate short gaps for inputs (not salinity)
#
# Short gaps in the input variables (discharge, tidal levels, rainfall) can create unnecessary breaks in the time series for modelling. In this section we interpolate only short gaps, defined here as up to three consecutive missing values, using time-based interpolation. Longer gaps remain as missing and will be handled later during model preparation. Salinity is **not** interpolated, so the target reflects observed values only. After interpolation, we print missingness summaries for each cleaned input series.

# %%
# Interpolate short gaps and rename columns for inputs

discharge_clean = {}
for name, df_qc in discharge_qc.items():
    df_clean = interpolate_short_gaps(df_qc, limit=3)
    # Rename columns to include the series name
    if df_clean.shape[1] == 1:
        df_clean.columns = [name]
    else:
        df_clean.columns = [f"{name}_{col}" for col in df_clean.columns]
    discharge_clean[name] = df_clean
    _ = missing_summary(df_clean, label=f"discharge '{name}' (clean, interpolated)")

tide_clean = {}
for name, df_qc in tide_qc.items():
    df_clean = interpolate_short_gaps(df_qc, limit=3)
    if df_clean.shape[1] == 1:
        df_clean.columns = [name]
    else:
        df_clean.columns = [f"{name}_{col}" for col in df_clean.columns]
    tide_clean[name] = df_clean
    _ = missing_summary(df_clean, label=f"tide '{name}' (clean, interpolated)")

rain_clean = {}
for name, df_qc in rain_qc.items():
    df_clean = interpolate_short_gaps(df_qc, limit=3)
    if df_clean.shape[1] == 1:
        df_clean.columns = [name]
    else:
        df_clean.columns = [f"{name}_{col}" for col in df_clean.columns]
    rain_clean[name] = df_clean
    _ = missing_summary(df_clean, label=f"rain '{name}' (clean, interpolated)")
# Out:
# ------------------------------------------------------------
# Missingness summary for discharge 'Q_MyThuan' (clean, interpolated)
#                             n  n_missing  pct_missing
# Q_MyThuan_Station Code  61321      45150        73.63
# Q_MyThuan_Value         61321      45150        73.63
# ------------------------------------------------------------
# Missingness summary for discharge 'Q_CanTho' (clean, interpolated)
#                            n  n_missing  pct_missing
# Q_CanTho_Station Code  61321      45640        74.43
# Q_CanTho_Value         61321      45640        74.43
# ------------------------------------------------------------
# Missingness summary for discharge 'Q_VamNao' (clean, interpolated)
#                            n  n_missing  pct_missing
# Q_VamNao_Station Code  61321      61321       100.00
# Q_VamNao_Value         61321      44142        71.99
# ------------------------------------------------------------
# Missingness summary for tide 'H_TanChau' (clean, interpolated)
#                              n  n_missing  pct_missing
# H_TanChau_Station Code  391465     391465       100.00
# H_TanChau_Value         391465     175837        44.92
# ------------------------------------------------------------
# Missingness summary for tide 'H_MyThuan' (clean, interpolated)
#                              n  n_missing  pct_missing
# H_MyThuan_Station Code  555841     555841       100.00
# H_MyThuan_Value         555841     347454        62.51
# ------------------------------------------------------------
# Missingness summary for tide 'H_MyTho' (clean, interpolated)
#                            n  n_missing  pct_missing
# H_MyTho_Station Code  245425     245425       100.00
# H_MyTho_Value         245425     176411        71.88
# ------------------------------------------------------------
# Missingness summary for tide 'H_ChoMoi' (clean, interpolated)
#                             n  n_missing  pct_missing
# H_ChoMoi_Station Code  287089     287089       100.00
# H_ChoMoi_Value         287089     206252        71.84
# ------------------------------------------------------------
# Missingness summary for tide 'H_CanTho' (clean, interpolated)
#                             n  n_missing  pct_missing
# H_CanTho_Station Code  391465     391465       100.00
# H_CanTho_Value         391465     186965        47.76
# ------------------------------------------------------------
# Missingness summary for tide 'H_DaiNgai' (clean, interpolated)
#                              n  n_missing  pct_missing
# H_DaiNgai_Station Code  245401     245401       100.00
# H_DaiNgai_Value         245401     176380        71.87
# ------------------------------------------------------------
# Missingness summary for tide 'H_ChoLach' (clean, interpolated)
#                              n  n_missing  pct_missing
# H_ChoLach_Station Code  227881     227881       100.00
# H_ChoLach_Value         227881     163970        71.95
# ------------------------------------------------------------
# Missingness summary for tide 'H_VamNao' (clean, interpolated)
#                             n  n_missing  pct_missing
# H_VamNao_Station Code  341017     341017       100.00
# H_VamNao_Value         341017     150292        44.07
# ------------------------------------------------------------
# Missingness summary for tide 'H_VamKenh' (clean, interpolated)
#                              n  n_missing  pct_missing
# H_VamKenh_Station Code  279673     279673       100.00
# H_VamKenh_Value         279673     139937        50.04
# ------------------------------------------------------------
# Missingness summary for tide 'H_TanHiep' (clean, interpolated)
#                              n  n_missing  pct_missing
# H_TanHiep_Station Code  245425     245425       100.00
# H_TanHiep_Value         245425     176404        71.88
# ------------------------------------------------------------
# Missingness summary for tide 'H_ViThanh' (clean, interpolated)
#                              n  n_missing  pct_missing
# H_ViThanh_Station Code  245401     245401       100.00
# H_ViThanh_Value         245401     178970        72.93
# ------------------------------------------------------------
# Missingness summary for tide 'H_CaiLay' (clean, interpolated)
#                             n  n_missing  pct_missing
# H_CaiLay_Station Code  227905     227905       100.00
# H_CaiLay_Value         227905     163987        71.95
# ------------------------------------------------------------
# Missingness summary for tide 'H_PhungHiep' (clean, interpolated)
#                               n  n_missing  pct_missing
# H_PhungHiep_Station Code  48034      48034       100.00
# H_PhungHiep_Value         48034       1950         4.06
# ------------------------------------------------------------
# Missingness summary for rain 'rain_MyThuan' (clean, interpolated)
#                                 n  n_missing  pct_missing
# rain_MyThuan_Station Code  151849          0          0.0
# rain_MyThuan_Value         151849          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_CaMau' (clean, interpolated)
#                               n  n_missing  pct_missing
# rain_CaMau_Station Code  289273          0          0.0
# rain_CaMau_Value         289273          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_ViThanh' (clean, interpolated)
#                                 n  n_missing  pct_missing
# rain_ViThanh_Station Code  289273          0          0.0
# rain_ViThanh_Value         289273          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_PhungHiep' (clean, interpolated)
#                                   n  n_missing  pct_missing
# rain_PhungHiep_Station Code  289273          0          0.0
# rain_PhungHiep_Value         289273          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_DaiNgai' (clean, interpolated)
#                                 n  n_missing  pct_missing
# rain_DaiNgai_Station Code  289273          0          0.0
# rain_DaiNgai_Value         289273          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_ChauDoc' (clean, interpolated)
#                                 n  n_missing  pct_missing
# rain_ChauDoc_Station Code  771097          0          0.0
# rain_ChauDoc_Value         771097          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_CanTho' (clean, interpolated)
#                                n  n_missing  pct_missing
# rain_CanTho_Station Code  771385          0          0.0
# rain_CanTho_Value         771385          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_TanChau' (clean, interpolated)
#                                n  n_missing  pct_missing
# rain_TanChau_Station Code  78889          0          0.0
# rain_TanChau_Value         78889          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_ChoMoi' (clean, interpolated)
#                               n  n_missing  pct_missing
# rain_ChoMoi_Station Code  78889          0          0.0
# rain_ChoMoi_Value         78889          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_TanHiep' (clean, interpolated)
#                                n  n_missing  pct_missing
# rain_TanHiep_Station Code  78889          0          0.0
# rain_TanHiep_Value         78889          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_MyTho' (clean, interpolated)
#                               n  n_missing  pct_missing
# rain_MyTho_Station Code  192841          0          0.0
# rain_MyTho_Value         192841          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_CaiLay' (clean, interpolated)
#                               n  n_missing  pct_missing
# rain_CaiLay_Station Code  78889          0          0.0
# rain_CaiLay_Value         78889          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_Batri' (clean, interpolated)
#                              n  n_missing  pct_missing
# rain_Batri_Station Code  78889          0          0.0
# rain_Batri_Value         78889          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_BenLuc' (clean, interpolated)
#                               n  n_missing  pct_missing
# rain_BenLuc_Station Code  78889          0          0.0
# rain_BenLuc_Value         78889          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_CaiBe' (clean, interpolated)
#                              n  n_missing  pct_missing
# rain_CaiBe_Station Code  78889          0          0.0
# rain_CaiBe_Value         78889          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_VamNao' (clean, interpolated)
#                                n  n_missing  pct_missing
# rain_VamNao_Station Code  142321          0          0.0
# rain_VamNao_Value         142321          0          0.0
# ------------------------------------------------------------
# Missingness summary for rain 'rain_VamKenh' (clean, interpolated)
#                                 n  n_missing  pct_missing
# rain_VamKenh_Station Code  119189      74850         62.8
# rain_VamKenh_Value         119189          0          0.0

# %% [markdown]
# # Merge variables and create per-station datasets
#
# Now we construct a common input feature matrix by aligning all cleaned discharge, tide, and rainfall series on the salinity time index. The merged input frame contains one column per input variable, with rows corresponding to time steps. For each salinity station, we then build a per-station data frame containing a single `salinity` column (the target) and all input variables at that station's time steps. Rows where salinity is missing are dropped so that the resulting datasets are ready for supervised learning.

# %%
# Build common input feature matrix X_inputs on salinity index
common_index = salinity_clean.index
X_inputs = pd.DataFrame(index=common_index)

# Join discharge inputs
for name, df_clean in discharge_clean.items():
    X_inputs = X_inputs.join(df_clean, how="outer")

# Join tidal level inputs
for name, df_clean in tide_clean.items():
    X_inputs = X_inputs.join(df_clean, how="outer")

# Join rainfall inputs
for name, df_clean in rain_clean.items():
    X_inputs = X_inputs.join(df_clean, how="outer")

# Optionally drop rows where all input variables are NaN
X_inputs = X_inputs.dropna(how="all")

print(f"Input feature matrix shape after merging: {X_inputs.shape}")
print(X_inputs.head())

# Create per-station datasets
station_data = {}
station_summaries = []

for station in SALINITY_STATION_COLS:
    sal_series = salinity_clean[station]

    n_before = len(sal_series)
    pct_missing_before = sal_series.isna().mean() * 100 if n_before > 0 else np.nan

    # Base frame on salinity index, with salinity as target
    df_station = pd.DataFrame(index=salinity_clean.index)
    df_station["salinity"] = sal_series

    # Inner join with inputs so that only common timestamps are retained
    df_station = df_station.join(X_inputs, how="inner")

    # Drop rows where salinity is missing
    df_station = df_station.dropna(subset=["salinity"])

    station_data[station] = df_station

    n_after = len(df_station)
    input_cols = [c for c in df_station.columns if c != "salinity"]
    if n_after > 0 and input_cols:
        pct_missing_inputs_after = df_station[input_cols].isna().mean().mean() * 100
    else:
        pct_missing_inputs_after = np.nan

    station_summaries.append(
        {
            "station": station,
            "n_before": n_before,
            "pct_missing_salinity_before": pct_missing_before,
            "n_after": n_after,
            "pct_missing_inputs_after": pct_missing_inputs_after,
            "start_after": df_station.index.min(),
            "end_after": df_station.index.max(),
        }
    )

# Inspect one example station (if available)
if station_data:
    first_station = next(iter(station_data))
    print(f"\nExample merged dataset for station '{first_station}':")
    print(station_data[first_station].head())
# Out:
# Input feature matrix shape after merging: (911080, 66)
#                      Q_MyThuan_Station Code  Q_MyThuan_Value  \
# 1920-01-01 00:00:00                     NaN              NaN
# 1920-01-01 01:00:00                     NaN              NaN
# 1920-01-01 02:00:00                     NaN              NaN
# 1920-01-01 03:00:00                     NaN              NaN
# 1920-01-01 04:00:00                     NaN              NaN
#
#                      Q_CanTho_Station Code  Q_CanTho_Value  \
# 1920-01-01 00:00:00                    NaN             NaN
# 1920-01-01 01:00:00                    NaN             NaN
# 1920-01-01 02:00:00                    NaN             NaN
# 1920-01-01 03:00:00                    NaN             NaN
# 1920-01-01 04:00:00                    NaN             NaN
#
#                      Q_VamNao_Station Code  Q_VamNao_Value  \
# 1920-01-01 00:00:00                    NaN             NaN
# 1920-01-01 01:00:00                    NaN             NaN
# 1920-01-01 02:00:00                    NaN             NaN
# 1920-01-01 03:00:00                    NaN             NaN
# 1920-01-01 04:00:00                    NaN             NaN
#
#                      H_TanChau_Station Code  H_TanChau_Value  \
# 1920-01-01 00:00:00                     NaN              NaN
# 1920-01-01 01:00:00                     NaN              NaN
# 1920-01-01 02:00:00                     NaN              NaN
# 1920-01-01 03:00:00                     NaN              NaN
# 1920-01-01 04:00:00                     NaN              NaN
#
#                      H_MyThuan_Station Code  H_MyThuan_Value  ...  \
# 1920-01-01 00:00:00                     NaN              NaN  ...
# 1920-01-01 01:00:00                     NaN              NaN  ...
# 1920-01-01 02:00:00                     NaN              NaN  ...
# 1920-01-01 03:00:00                     NaN              NaN  ...
# 1920-01-01 04:00:00                     NaN              NaN  ...
#
#                      rain_Batri_Station Code  rain_Batri_Value  \
# 1920-01-01 00:00:00                      NaN               NaN
# 1920-01-01 01:00:00                      NaN               NaN
# 1920-01-01 02:00:00                      NaN               NaN
# 1920-01-01 03:00:00                      NaN               NaN
# 1920-01-01 04:00:00                      NaN               NaN
#
#                      rain_BenLuc_Station Code  rain_BenLuc_Value  \
# 1920-01-01 00:00:00                       NaN                NaN
# 1920-01-01 01:00:00                       NaN                NaN
# 1920-01-01 02:00:00                       NaN                NaN
# 1920-01-01 03:00:00                       NaN                NaN
# 1920-01-01 04:00:00                       NaN                NaN
#
#                      rain_CaiBe_Station Code  rain_CaiBe_Value  \
# 1920-01-01 00:00:00                      NaN               NaN
# 1920-01-01 01:00:00                      NaN               NaN
# 1920-01-01 02:00:00                      NaN               NaN
# 1920-01-01 03:00:00                      NaN               NaN
# 1920-01-01 04:00:00                      NaN               NaN
#
#                      rain_VamNao_Station Code  rain_VamNao_Value  \
# 1920-01-01 00:00:00                       NaN                NaN
# 1920-01-01 01:00:00                       NaN                NaN
# 1920-01-01 02:00:00                       NaN                NaN
# 1920-01-01 03:00:00                       NaN                NaN
# 1920-01-01 04:00:00                       NaN                NaN
#
#                      rain_VamKenh_Station Code  rain_VamKenh_Value
# 1920-01-01 00:00:00                        NaN                 NaN
# 1920-01-01 01:00:00                        NaN                 NaN
# 1920-01-01 02:00:00                        NaN                 NaN
# 1920-01-01 03:00:00                        NaN                 NaN
# 1920-01-01 04:00:00                        NaN                 NaN
#
# [5 rows x 66 columns]
#
# Example merged dataset for station 'AnDinh':
#                      salinity  Q_MyThuan_Station Code  Q_MyThuan_Value  \
# 1996-02-02 03:00:00       0.1                     NaN              NaN
# 1996-02-02 05:00:00       0.1                     NaN              NaN
# 1996-02-02 07:00:00       0.1                     NaN              NaN
# 1996-02-04 17:00:00       0.1                     NaN              NaN
# 1996-02-04 19:00:00       0.1                     NaN              NaN
#
#                      Q_CanTho_Station Code  Q_CanTho_Value  \
# 1996-02-02 03:00:00                    NaN             NaN
# 1996-02-02 05:00:00                    NaN             NaN
# 1996-02-02 07:00:00                    NaN             NaN
# 1996-02-04 17:00:00                    NaN             NaN
# 1996-02-04 19:00:00                    NaN             NaN
#
#                      Q_VamNao_Station Code  Q_VamNao_Value  \
# 1996-02-02 03:00:00                    NaN             NaN
# 1996-02-02 05:00:00                    NaN             NaN
# 1996-02-02 07:00:00                    NaN             NaN
# 1996-02-04 17:00:00                    NaN             NaN
# 1996-02-04 19:00:00                    NaN             NaN
#
#                      H_TanChau_Station Code  H_TanChau_Value  \
# 1996-02-02 03:00:00                     NaN             1.08
# 1996-02-02 05:00:00                     NaN              NaN
# 1996-02-02 07:00:00                     NaN              NaN
# 1996-02-04 17:00:00                     NaN              NaN
# 1996-02-04 19:00:00                     NaN              NaN
#
#                      H_MyThuan_Station Code  ...  rain_Batri_Station Code  \
# 1996-02-02 03:00:00                     NaN  ...                      NaN
# 1996-02-02 05:00:00                     NaN  ...                      NaN
# 1996-02-02 07:00:00                     NaN  ...                      NaN
# 1996-02-04 17:00:00                     NaN  ...                      NaN
# 1996-02-04 19:00:00                     NaN  ...                      NaN
#
#                      rain_Batri_Value  rain_BenLuc_Station Code  \
# 1996-02-02 03:00:00               NaN                       NaN
# 1996-02-02 05:00:00               NaN                       NaN
# 1996-02-02 07:00:00               NaN                       NaN
# 1996-02-04 17:00:00               NaN                       NaN
# 1996-02-04 19:00:00               NaN                       NaN
#
#                      rain_BenLuc_Value  rain_CaiBe_Station Code  \
# 1996-02-02 03:00:00                NaN                      NaN
# 1996-02-02 05:00:00                NaN                      NaN
# 1996-02-02 07:00:00                NaN                      NaN
# 1996-02-04 17:00:00                NaN                      NaN
# 1996-02-04 19:00:00                NaN                      NaN
#
#                      rain_CaiBe_Value  rain_VamNao_Station Code  \
# 1996-02-02 03:00:00               NaN                       NaN
# 1996-02-02 05:00:00               NaN                       NaN
# 1996-02-02 07:00:00               NaN                       NaN
# 1996-02-04 17:00:00               NaN                       NaN
# 1996-02-04 19:00:00               NaN                       NaN
#
#                      rain_VamNao_Value  rain_VamKenh_Station Code  \
# 1996-02-02 03:00:00                NaN                        NaN
# 1996-02-02 05:00:00                NaN                        NaN
# 1996-02-02 07:00:00                NaN                        NaN
# 1996-02-04 17:00:00                NaN                        NaN
# 1996-02-04 19:00:00                NaN                        NaN
#
#                      rain_VamKenh_Value
# 1996-02-02 03:00:00                 NaN
# 1996-02-02 05:00:00                 NaN
# 1996-02-02 07:00:00                 NaN
# 1996-02-04 17:00:00                 NaN
# 1996-02-04 19:00:00                 NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# # Save outputs and print summary
#
# Finally, each station-specific merged dataset is written to `data/clean/` as a separate CSV file named `station_<station_name>.csv`. The index is saved as a `datetime` column so that it can be read easily in later notebooks or scripts. A compact summary table is printed showing, for each station, the number of rows and percentage of missing data before cleaning (for salinity) and after cleaning (for the inputs), along with the date range of the final dataset. This provides a quick overview of data availability for subsequent LSTM modelling experiments.

# %%
# Save per-station datasets to disk
for station, df_station in station_data.items():
    # Make station name safe for filenames
    safe_station = "".join(
        c if c.isalnum() or c in ("-", "_") else "_"
        for c in str(station)
    )
    out_path = CLEAN_DIR / f"station_{safe_station}.csv"
    df_station.to_csv(out_path, index_label="datetime")
    print(f"Saved cleaned dataset for station {station!r} to {out_path}")

# Build and print overall summary table
summary_df = pd.DataFrame(station_summaries)

if not summary_df.empty:
    # Format dates for readability
    summary_df["start_after"] = summary_df["start_after"].dt.strftime("%Y-%m-%d %H:%M:%S")
    summary_df["end_after"] = summary_df["end_after"].dt.strftime("%Y-%m-%d %H:%M:%S")
    summary_df = summary_df.set_index("station")

    print("\nOverview of per-station datasets (before/after cleaning):")
    print(summary_df[[
        "n_before",
        "pct_missing_salinity_before",
        "n_after",
        "pct_missing_inputs_after",
        "start_after",
        "end_after",
    ]].round(2))
else:
    print("No station datasets were created; please check the salinity inputs and configuration.")
# Out:
# Saved cleaned dataset for station 'AnDinh' to C:\Users\User\Desktop\Disertation\data\clean\station_AnDinh.csv
# Saved cleaned dataset for station 'AnLacTay' to C:\Users\User\Desktop\Disertation\data\clean\station_AnLacTay.csv
# Saved cleaned dataset for station 'AnNinh' to C:\Users\User\Desktop\Disertation\data\clean\station_AnNinh.csv
# Saved cleaned dataset for station 'AnThuan' to C:\Users\User\Desktop\Disertation\data\clean\station_AnThuan.csv
# Saved cleaned dataset for station 'BenLuc' to C:\Users\User\Desktop\Disertation\data\clean\station_BenLuc.csv
# Saved cleaned dataset for station 'BenTrai' to C:\Users\User\Desktop\Disertation\data\clean\station_BenTrai.csv
# Saved cleaned dataset for station 'BinhDai' to C:\Users\User\Desktop\Disertation\data\clean\station_BinhDai.csv
# Saved cleaned dataset for station 'CaMau' to C:\Users\User\Desktop\Disertation\data\clean\station_CaMau.csv
# Saved cleaned dataset for station 'CauNoi' to C:\Users\User\Desktop\Disertation\data\clean\station_CauNoi.csv
# Saved cleaned dataset for station 'CauQuan' to C:\Users\User\Desktop\Disertation\data\clean\station_CauQuan.csv
# Saved cleaned dataset for station 'DaiNgai' to C:\Users\User\Desktop\Disertation\data\clean\station_DaiNgai.csv
# Saved cleaned dataset for station 'DongTam' to C:\Users\User\Desktop\Disertation\data\clean\station_DongTam.csv
# Saved cleaned dataset for station 'GanhHao' to C:\Users\User\Desktop\Disertation\data\clean\station_GanhHao.csv
# Saved cleaned dataset for station 'GiongTrom' to C:\Users\User\Desktop\Disertation\data\clean\station_GiongTrom.csv
# Saved cleaned dataset for station 'GoQuao' to C:\Users\User\Desktop\Disertation\data\clean\station_GoQuao.csv
# Saved cleaned dataset for station 'HoaBinh' to C:\Users\User\Desktop\Disertation\data\clean\station_HoaBinh.csv
# Saved cleaned dataset for station 'HungMy' to C:\Users\User\Desktop\Disertation\data\clean\station_HungMy.csv
# Saved cleaned dataset for station 'HuongMy' to C:\Users\User\Desktop\Disertation\data\clean\station_HuongMy.csv
# Saved cleaned dataset for station 'KhanhThanhTan' to C:\Users\User\Desktop\Disertation\data\clean\station_KhanhThanhTan.csv
# Saved cleaned dataset for station 'LocThuan' to C:\Users\User\Desktop\Disertation\data\clean\station_LocThuan.csv
# Saved cleaned dataset for station 'LongPhu' to C:\Users\User\Desktop\Disertation\data\clean\station_LongPhu.csv
# Saved cleaned dataset for station 'LuynhQuynh' to C:\Users\User\Desktop\Disertation\data\clean\station_LuynhQuynh.csv
# Saved cleaned dataset for station 'MyHoa' to C:\Users\User\Desktop\Disertation\data\clean\station_MyHoa.csv
# Saved cleaned dataset for station 'MyTho' to C:\Users\User\Desktop\Disertation\data\clean\station_MyTho.csv
# Saved cleaned dataset for station 'PhuocLong' to C:\Users\User\Desktop\Disertation\data\clean\station_PhuocLong.csv
# Saved cleaned dataset for station 'RachGia' to C:\Users\User\Desktop\Disertation\data\clean\station_RachGia.csv
# Saved cleaned dataset for station 'SocTrang' to C:\Users\User\Desktop\Disertation\data\clean\station_SocTrang.csv
# Saved cleaned dataset for station 'SonDoc' to C:\Users\User\Desktop\Disertation\data\clean\station_SonDoc.csv
# Saved cleaned dataset for station 'SongDoc' to C:\Users\User\Desktop\Disertation\data\clean\station_SongDoc.csv
# Saved cleaned dataset for station 'TamNgan' to C:\Users\User\Desktop\Disertation\data\clean\station_TamNgan.csv
# Saved cleaned dataset for station 'TanAn' to C:\Users\User\Desktop\Disertation\data\clean\station_TanAn.csv
# Saved cleaned dataset for station 'ThanhPhu' to C:\Users\User\Desktop\Disertation\data\clean\station_ThanhPhu.csv
# Saved cleaned dataset for station 'ThoiBinh' to C:\Users\User\Desktop\Disertation\data\clean\station_ThoiBinh.csv
# Saved cleaned dataset for station 'TPBacLieu' to C:\Users\User\Desktop\Disertation\data\clean\station_TPBacLieu.csv
# Saved cleaned dataset for station 'TraKha' to C:\Users\User\Desktop\Disertation\data\clean\station_TraKha.csv
# Saved cleaned dataset for station 'TranDe' to C:\Users\User\Desktop\Disertation\data\clean\station_TranDe.csv
# Saved cleaned dataset for station 'TraVinh' to C:\Users\User\Desktop\Disertation\data\clean\station_TraVinh.csv
# Saved cleaned dataset for station 'TuyenNhon' to C:\Users\User\Desktop\Disertation\data\clean\station_TuyenNhon.csv
# Saved cleaned dataset for station 'VamKenh' to C:\Users\User\Desktop\Disertation\data\clean\station_VamKenh.csv
# Saved cleaned dataset for station 'VungLiem' to C:\Users\User\Desktop\Disertation\data\clean\station_VungLiem.csv
# Saved cleaned dataset for station 'XeoRo' to C:\Users\User\Desktop\Disertation\data\clean\station_XeoRo.csv
# Saved cleaned dataset for station 'XuanKhanh' to C:\Users\User\Desktop\Disertation\data\clean\station_XuanKhanh.csv
#
# Overview of per-station datasets (before/after cleaning):
#                n_before  pct_missing_salinity_before  n_after  \
# station
# AnDinh           239493                        92.53    17892
# AnLacTay         239493                       100.00        0
# AnNinh           239493                       100.00        0
# AnThuan          239493                       100.00        0
# BenLuc           239493                       100.00        0
# BenTrai          239493                       100.00        0
# BinhDai          239493                       100.00        0
# CaMau            239493                       100.00        0
# CauNoi           239493                       100.00        0
# CauQuan          239493                       100.00        0
# DaiNgai          239493                       100.00        0
# DongTam          239493                       100.00        0
# GanhHao          239493                       100.00        0
# GiongTrom        239493                       100.00        0
# GoQuao           239493                       100.00        0
# HoaBinh          239493                       100.00        0
# HungMy           239493                       100.00        0
# HuongMy          239493                       100.00        0
# KhanhThanhTan    239493                       100.00        0
# LocThuan         239493                       100.00        0
# LongPhu          239493                       100.00        0
# LuynhQuynh       239493                       100.00        0
# MyHoa            239493                       100.00        0
# MyTho            239493                       100.00        0
# PhuocLong        239493                       100.00        0
# RachGia          239493                       100.00        0
# SocTrang         239493                       100.00        0
# SonDoc           239493                       100.00        0
# SongDoc          239493                       100.00        0
# TamNgan          239493                       100.00        0
# TanAn            239493                       100.00        0
# ThanhPhu         239493                       100.00        0
# ThoiBinh         239493                       100.00        0
# TPBacLieu        239493                       100.00        0
# TraKha           239493                       100.00        0
# TranDe           239493                       100.00        0
# TraVinh          239493                       100.00        0
# TuyenNhon        239493                       100.00        0
# VamKenh          239493                       100.00        0
# VungLiem         239493                       100.00        0
# XeoRo            239493                       100.00        0
# XuanKhanh        239493                       100.00        0
#
#                pct_missing_inputs_after          start_after  \
# station
# AnDinh                             67.0  1996-02-02 03:00:00
# AnLacTay                            NaN                  NaN
# AnNinh                              NaN                  NaN
# AnThuan                             NaN                  NaN
# BenLuc                              NaN                  NaN
# BenTrai                             NaN                  NaN
# BinhDai                             NaN                  NaN
# CaMau                               NaN                  NaN
# CauNoi                              NaN                  NaN
# CauQuan                             NaN                  NaN
# DaiNgai                             NaN                  NaN
# DongTam                             NaN                  NaN
# GanhHao                             NaN                  NaN
# GiongTrom                           NaN                  NaN
# GoQuao                              NaN                  NaN
# HoaBinh                             NaN                  NaN
# HungMy                              NaN                  NaN
# HuongMy                             NaN                  NaN
# KhanhThanhTan                       NaN                  NaN
# LocThuan                            NaN                  NaN
# LongPhu                             NaN                  NaN
# LuynhQuynh                          NaN                  NaN
# MyHoa                               NaN                  NaN
# MyTho                               NaN                  NaN
# PhuocLong                           NaN                  NaN
# RachGia                             NaN                  NaN
# SocTrang                            NaN                  NaN
# SonDoc                              NaN                  NaN
# SongDoc                             NaN                  NaN
# TamNgan                             NaN                  NaN
# TanAn                               NaN                  NaN
# ThanhPhu                            NaN                  NaN
# ThoiBinh                            NaN                  NaN
# TPBacLieu                           NaN                  NaN
# TraKha                              NaN                  NaN
# TranDe                              NaN                  NaN
# TraVinh                             NaN                  NaN
# TuyenNhon                           NaN                  NaN
# VamKenh                             NaN                  NaN
# VungLiem                            NaN                  NaN
# XeoRo                               NaN                  NaN
# XuanKhanh                           NaN                  NaN
#
#                          end_after
# station
# AnDinh         2023-05-29 23:00:00
# AnLacTay                       NaN
# AnNinh                         NaN
# AnThuan                        NaN
# BenLuc                         NaN
# BenTrai                        NaN
# BinhDai                        NaN
# CaMau                          NaN
# CauNoi                         NaN
# CauQuan                        NaN
# DaiNgai                        NaN
# DongTam                        NaN
# GanhHao                        NaN
# GiongTrom                      NaN
# GoQuao                         NaN
# HoaBinh                        NaN
# HungMy                         NaN
# HuongMy                        NaN
# KhanhThanhTan                  NaN
# LocThuan                       NaN
# LongPhu                        NaN
# LuynhQuynh                     NaN
# MyHoa                          NaN
# MyTho                          NaN
# PhuocLong                      NaN
# RachGia                        NaN
# SocTrang                       NaN
# SonDoc                         NaN
# SongDoc                        NaN
# TamNgan                        NaN
# TanAn                          NaN
# ThanhPhu                       NaN
# ThoiBinh                       NaN
# TPBacLieu                      NaN
# TraKha                         NaN
# TranDe                         NaN
# TraVinh                        NaN
# TuyenNhon                      NaN
# VamKenh                        NaN
# VungLiem                       NaN
# XeoRo                          NaN
# XuanKhanh                      NaN
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
